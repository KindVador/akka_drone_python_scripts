# %%
# %pylab inline
import px4tools
from px4tools import pandas

plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['lines.linewidth'] = 3
# Out:
# Populating the interactive namespace from numpy and matplotlib
# No module named 'mpl_toolkits.basemap'
#
# WARNING: mapping module requires basemap
#     sudo apt-get install python-basemap
#     or:
#     conda install basemap
#
# No module named 'mpl_toolkits.basemap'

# %%
d = px4tools.read_ulog('/Users/florian/Downloads/23_43_25.ulg')

# %%
type(d)
# Out:
# px4tools.ulog.PX4MessageDict

# %%
dir(d)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'clear',
#  'concat',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'set_with_dict',
#  'setdefault',
#  't_actuator_controls_0_0',
#  't_actuator_outputs_0',
#  't_actuator_outputs_1',
#  't_battery_status_0',
#  't_cpuload_0',
#  't_ekf2_innovations_0',
#  't_ekf2_timestamps_0',
#  't_estimator_status_0',
#  't_home_position_0',
#  't_input_rc_0',
#  't_manual_control_setpoint_0',
#  't_mission_result_0',
# ...

# %%
d.keys()
# Out:
# dict_keys(['t_sensor_baro_0', 't_ekf2_timestamps_0', 't_wind_estimate_0', 't_vehicle_status_flags_0', 't_vehicle_status_0', 't_vehicle_rates_setpoint_0', 't_vehicle_local_position_setpoint_0', 't_vehicle_local_position_0', 't_vehicle_land_detected_0', 't_vehicle_gps_position_0', 't_vehicle_global_position_0', 't_vehicle_command_0', 't_vehicle_attitude_setpoint_0', 't_vehicle_attitude_0', 't_telemetry_status_0', 't_system_power_0', 't_sensor_preflight_0', 't_sensor_combined_0', 't_position_setpoint_triplet_0', 't_mission_result_0', 't_manual_control_setpoint_0', 't_input_rc_0', 't_home_position_0', 't_estimator_status_0', 't_ekf2_innovations_0', 't_cpuload_0', 't_battery_status_0', 't_actuator_outputs_1', 't_actuator_outputs_0', 't_actuator_controls_0_0'])

# %%
d.t_estimator_status_0
# Out:
#                  timestamp  f_states_0_  f_states_1_  f_states_2_  \
# 00:05:07.272290  307272290     0.328421    -0.004604     0.030799
# 00:05:07.477073  307477073     0.328421    -0.004537     0.031297
# 00:05:07.677812  307677812     0.328335    -0.004532     0.031589
# 00:05:07.878726  307878726     0.328761    -0.004686     0.031576
# 00:05:08.082508  308082508     0.330873    -0.004633     0.031460
# 00:05:08.283501  308283501     0.331100    -0.004674     0.031809
# 00:05:08.484202  308484202     0.329301    -0.005108     0.031626
# 00:05:08.684991  308684991     0.328672    -0.004967     0.031653
# 00:05:08.888938  308888938     0.328100    -0.005045     0.031509
# 00:05:09.089754  309089754     0.326792    -0.004770     0.031361
# 00:05:09.295027  309295027     0.324446    -0.005291     0.031329
# 00:05:09.494703  309494703     0.323638    -0.005077     0.031447
# 00:05:09.699357  309699357     0.322166    -0.005087     0.031508
# ...
